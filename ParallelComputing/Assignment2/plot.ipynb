# %%
import matplotlib.pyplot as plt
import numpy as np
x=np.array([1,2,4,8,16])
y=np.array([1,1.87,2.32,3.65,6.02])
plt.plot(x,y,"x",color="red")
plt.plot(x,y,color="coral")
plt.xlabel("# of threads")
plt.ylabel("Speedup")
plt.savefig(r"speedup.pdf",format="pdf")
plt.show()
